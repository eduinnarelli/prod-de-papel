# %% [markdown]
# ## **Geração de Instâncias**

# %%
import pickle

# %% [markdown]
# #### Escolha <ins>**uma**</ins> das opções:
#
# **1 - Instâncias fixas:** a célula abaixo pega as instâncias que geramos, executamos e relatamos do arquivo `fixed_instances.pkl`, as salvando na lista de instâncias `instances`.

# %%
# Carregar instâncias em 'fixed_instances.pkl'
with open("fixed_instances.pkl", "rb") as fp:
    instances = pickle.load(fp)

# %% [markdown]
# **2 - Novas instâncias:** a célula abaixo gera novas instâncias diferentes da que testamos, as salvando no arquivo `instances.pkl` e na lista de instâncias `instances`.

# %%
from numpy.random import randint

instances = []

# Uma instância será criada p/ cada nº de clientes abaixo
num_of_clients_list = (50, 100, 150, 200, 250, 300, 350, 400, 450, 500)

for J in num_of_clients_list:
    
    F = randint(J, 2*J) # Fábricas
    L = randint(5, 10) # Máquinas
    M = randint(5, 10) # Tipos de matéria-prima
    P = randint(5, 10) # Tipos de papel
    D = randint(10, 20, size=(J, P)) # Demanda do cliente 'j' em papel 'p'
    r = randint(1, 5, size=(M, P, L)) # Qtd. de 'm' p/ prod. 1 'p' na máq. 'l'
    R = randint(800, 1000, size=(M, F)) # Qtd. de 'm' em cada fábrica 'f'
    C = randint(80, 100, size=(L, F)) # Cap. de prod. da máq. 'l' na fábrica 'f'
    p = randint(10, 100, size=(P, L, F)) # Custo de prod. 'p' usando máq. 'l' na fábrica 'f'
    t = randint(10, 20, size=(P, F, J)) # Custo de transp. 'p' da fábrica 'f' ao cliente 'j'
    
    # Salvar cada instância em um dicionário
    instances.append({
        "J": J,
        "F": F,
        "L": L,
        "M": M,
        "P": P,
        "D": D,
        "r": r,
        "R": R,
        "C": C,
        "p": p,
        "t": t,
    })

# Salvar instâncias em 'instances.pkl' 
with open('instances.pkl', 'wb') as output:
    pickle.dump(instances, output)

# %% [markdown]
# ## **Definição do Modelo**

# %%
from gurobipy import GRB
import gurobipy as gp

def create_model(inst, relaxed = False):
    '''
    Função que define o modelo para o Problema de Produção de Papel,
    seja ele o modelo de PLI (se 'relaxed' for 'False') ou o modelo 
    relaxado de PL (se 'relaxed' for 'True').
    '''
            
    # Inicializar modelo vazio
    model = gp.Model('paper-production')
    
    # Limitar tempo de execução em 30 minutos
    model.setParam('TimeLimit', 1800) 
    
    # O tipo das variáveis é inteiro por default e contínuo para o modelo
    # com as restrições de integralidade relaxadas
    vtype = (GRB.INTEGER if not relaxed else GRB.CONTINUOUS)

    # Variáveis de decisão:
    # - x[p, l, f]: qtd. de papel 'p' produzida na máq. 'l' da fábrica 'f';
    x = model.addVars(inst['P'], inst['L'], inst['F'], vtype=vtype)
    # - y[p, f, j]: qtd. de papel 'p' transp. da fábrica 'f' até o cliente 'j';
    y = model.addVars(inst['P'], inst['F'], inst['J'], vtype=vtype)

    # Objetivo:
    model.setObjective(
        # minimizar custo de produção...
        gp.quicksum(inst['p'][p,l,f] * x[p,l,f] for p in range(inst['P']) 
                                                for l in range(inst['L']) 
                                                for f in range(inst['F'])) +
        # e o de transporte
        gp.quicksum(inst['t'][p,f,j] * y[p,f,j] for p in range(inst['P']) 
                                                for f in range(inst['F']) 
                                                for j in range(inst['J']))
    )        

    # Restrições:
    # - não transportar mais do que é produzido;
    model.addConstrs((x.sum(p, '*', f) >= y.sum(p, f, '*') for p in range(inst['P'])
                                                           for f in range(inst['F'])), name='link_xy')
    # - atender demanda dos clientes;
    model.addConstrs((y.sum(p, '*', j) >= inst['D'][j, p] for p in range(inst['P']) 
                                                          for j in range(inst['J'])), name='dem')
    # - não ultrapassar capacidade das máquinas;
    model.addConstrs((x.sum('*', l, f) <= inst['C'][l, f] for l in range(inst['L']) 
                                                          for f in range(inst['F'])), name='cap')
    # - não exceder qtd. disponível de matéria-prima;
    model.addConstrs(
        (
            # a qtd. de matéria usada na máq. 'm' da fáb. 'f' não pode exceder R[m,f]...
            gp.quicksum(inst['r'][m, p, l] * x[p, l, f] for p in range(inst['P']) 
                                                        for l in range(inst['L'])) 
            <= inst['R'][m, f]
            # ... para toda máquina e fábrica
            for m in range(inst['M'])
            for f in range(inst['F']) 
        ), name='mp'
    )
    
    return model

# %% [markdown]
# ## **Testes**
#
# Os testes são executados sob as instâncias salvas na lista `instances`, que depende de qual célula foi executada no início desse Notebook.
#
# #### **Modelo PLI**: sem as restrições de integralidade relaxadas.

# %%
for inst in instances:
    print('\nSOL. DA INSTÂNCIA COM ' + str(inst['J']) + ' CLIENTES:\n')
    
    # Criar modelo
    model = create_model(inst)
    
    # Computar solução ótima
    model.optimize()
    
    # Relatar outros dados
    print(
        '\nTempo de execução: ' + 
        str(model.runTime) + 
        '; Número de variáveis: ' + 
        str(model.numVars) + 
        '\n'
    )
# Out:
# SOL. DA INSTÂNCIA COM 50 CLIENTES:
#
# Changed value of parameter TimeLimit to 1800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (linux64)
# Optimize a model with 2122 rows, 36736 columns and 101024 nonzeros
# Model fingerprint: 0x914ce4ec
# Variable types: 0 continuous, 36736 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
# Found heuristic solution: objective 416139.00000
# Presolve time: 0.09s
# Presolved: 2122 rows, 36736 columns, 101024 nonzeros
# Variable types: 0 continuous, 36736 integer (0 binary)
#
# Root relaxation: objective 1.222440e+05, 3332 iterations, 0.06 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# H    0     0                    122244.00000    0.00000   100%     -    0s
#      0     0 122244.000    0   10 122244.000 122244.000  0.00%     -    0s
#
# Explored 0 nodes (3730 simplex iterations) in 0.20 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 122244 416139
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.222440000000e+05, best bound 1.222440000000e+05, gap 0.0000%
#
# Tempo de execução: 0.20410919189453125; Número de variáveis: 36736
#
#
# SOL. DA INSTÂNCIA COM 100 CLIENTES:
#
# Changed value of parameter TimeLimit to 1800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (linux64)
# Optimize a model with 2912 rows, 72360 columns and 171520 nonzeros
# Model fingerprint: 0x6a27bd8c
# Variable types: 0 continuous, 72360 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
# Found heuristic solution: objective 502465.00000
# Presolve time: 0.21s
# Presolved: 2912 rows, 72360 columns, 171520 nonzeros
# Variable types: 0 continuous, 72360 integer (0 binary)
#
# Root relaxation: objective 1.483870e+05, 4288 iterations, 0.12 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    148387.00000 148387.000  0.00%     -    0s
#
# Explored 0 nodes (4288 simplex iterations) in 0.43 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 148387 502465
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.483870000000e+05, best bound 1.483870000000e+05, gap 0.0000%
#
# Tempo de execução: 0.4330260753631592; Número de variáveis: 72360
#
#
# SOL. DA INSTÂNCIA COM 150 CLIENTES:
#
# Changed value of parameter TimeLimit to 1800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (linux64)
# Optimize a model with 6468 rows, 279930 columns and 641130 nonzeros
# Model fingerprint: 0xab99b3bd
# Variable types: 0 continuous, 279930 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
# Found heuristic solution: objective 1069835.0000
# Presolve time: 0.95s
# Presolved: 6468 rows, 279930 columns, 641130 nonzeros
# Variable types: 0 continuous, 279930 integer (0 binary)
#
# Root relaxation: objective 3.112995e+05, 11360 iterations, 0.66 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 311299.500    0   10 1069835.00 311299.500  70.9%     -    2s
# H    0     0                    311300.00000 311299.500  0.00%     -    2s
#      0     0 311299.500    0   10 311300.000 311299.500  0.00%     -    2s
#
# Explored 1 nodes (15869 simplex iterations) in 2.19 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 311300 1.06984e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 3.113000000000e+05, best bound 3.113000000000e+05, gap 0.0000%
#
# Tempo de execução: 2.2012479305267334; Número de variáveis: 279930
#
#
# SOL. DA INSTÂNCIA COM 200 CLIENTES:
#
# Changed value of parameter TimeLimit to 1800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (linux64)
# Optimize a model with 6460 rows, 398520 columns and 865080 nonzeros
# Model fingerprint: 0xcfd0f3a1
# Variable types: 0 continuous, 398520 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
# Found heuristic solution: objective 1591522.0000
# Presolve time: 1.50s
# Presolved: 6460 rows, 398520 columns, 865080 nonzeros
# Variable types: 0 continuous, 398520 integer (0 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity      0.0000000e+00      2s
#        1      11174   2.1150608e+09   1.4348534e+05      2s
#        2      22725   1.0293394e+09   2.2399684e+05      2s
#        3      33002   9.0883044e+08   2.7550684e+05      2s
#        4      42584   4.8761038e+05   4.0311768e+05      2s
#        5      53038   4.8721112e+05   4.5630801e+05      2s
#        6      62567   4.8698688e+05   4.8258465e+05      3s
#
# Sifting complete
#
#
# Root relaxation: objective 4.869869e+05, 70947 iterations, 1.07 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 486986.875    0   55 1591522.00 486986.875  69.4%     -    3s
# H    0     0                    486991.00000 486986.875  0.00%     -    3s
#
# Explored 1 nodes (80906 simplex iterations) in 3.57 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 486991 1.59152e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 4.869910000000e+05, best bound 4.869870000000e+05, gap 0.0008%
#
# Tempo de execução: 3.578028917312622; Número de variáveis: 398520
#
#
# SOL. DA INSTÂNCIA COM 250 CLIENTES:
#
# Changed value of parameter TimeLimit to 1800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (linux64)
# Optimize a model with 12094 rows, 997668 columns and 2168676 nonzeros
# Model fingerprint: 0x32caefc8
# Variable types: 0 continuous, 997668 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
# Found heuristic solution: objective 2288659.0000
# Presolve time: 4.27s
# Presolved: 12094 rows, 997668 columns, 2168676 nonzeros
# Variable types: 0 continuous, 997668 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4551470e+06   2.168875e+03   4.023267e+11      6s
# Concurrent spin time: 0.45s
#
# Solved with dual simplex
#
# Root relaxation: objective 6.592858e+05, 79160 iterations, 2.95 seconds
# Total elapsed time = 10.06s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 659285.750    0   26 2288659.00 659285.750  71.2%     -   11s
# H    0     0                    659287.00000 659285.750  0.00%     -   11s
#
# Explored 1 nodes (148909 simplex iterations) in 11.85 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 659287 2.28866e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.592870000000e+05, best bound 6.592860000000e+05, gap 0.0002%
#
# Tempo de execução: 11.87073802947998; Número de variáveis: 997668
#
#
# SOL. DA INSTÂNCIA COM 300 CLIENTES:
#
# Changed value of parameter TimeLimit to 1800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (linux64)
# Optimize a model with 9058 rows, 699060 columns and 1489800 nonzeros
# Model fingerprint: 0x6855893f
# Variable types: 0 continuous, 699060 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
# Found heuristic solution: objective 1814356.0000
# Presolve time: 3.51s
# Presolved: 9058 rows, 699060 columns, 1489800 nonzeros
# Variable types: 0 continuous, 699060 integer (0 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity      0.0000000e+00      4s
#        1      14457   2.0569814e+09   1.2377240e+05      4s
#        2      28013   1.2751951e+09   3.3953746e+05      4s
#        3      39996   5.3956657e+05   4.5583716e+05      5s
#        4      52308   5.3945357e+05   5.2340450e+05      5s
#
# Sifting complete
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    63811    5.3945357e+05   0.000000e+00   0.000000e+00      5s
#
# Root relaxation: objective 5.394536e+05, 63811 iterations, 1.41 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 539453.567    0   42 1814356.00 539453.567  70.3%     -   11s
# H    0     0                    539455.00000 539453.567  0.00%     -   12s
#
# Explored 1 nodes (372230 simplex iterations) in 12.21 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 539455 1.81436e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.394550000000e+05, best bound 5.394540000000e+05, gap 0.0002%
#
# Tempo de execução: 12.22695803642273; Número de variáveis: 699060
#
#
# SOL. DA INSTÂNCIA COM 350 CLIENTES:
#
# Changed value of parameter TimeLimit to 1800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (linux64)
# Optimize a model with 12482 rows, 1319472 columns and 2768304 nonzeros
# Model fingerprint: 0x5525754a
# Variable types: 0 continuous, 1319472 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
# Found heuristic solution: objective 2466244.0000
# Presolve time: 4.01s
# Presolved: 12482 rows, 1319472 columns, 2768304 nonzeros
# Variable types: 0 continuous, 1319472 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4738340e+06   2.469062e+03   5.195871e+11      6s
# Concurrent spin time: 1.47s
#
# Solved with dual simplex
#
# Root relaxation: objective 7.241845e+05, 113610 iterations, 5.33 seconds
# Total elapsed time = 12.14s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 724184.500    0   60 2466244.00 724184.500  70.6%     -   14s
# H    0     0                    724187.00000 724184.500  0.00%     -   15s
#
# Explored 1 nodes (269043 simplex iterations) in 15.59 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 724187 2.46624e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.241870000000e+05, best bound 7.241845000000e+05, gap 0.0003%
#
# Tempo de execução: 15.610584020614624; Número de variáveis: 1319472
#
#
# SOL. DA INSTÂNCIA COM 400 CLIENTES:
#
# Changed value of parameter TimeLimit to 1800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (linux64)
# Optimize a model with 11810 rows, 1109075 columns and 2332600 nonzeros
# Model fingerprint: 0x0c64a09d
# Variable types: 0 continuous, 1109075 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
# Found heuristic solution: objective 1982220.0000
# Presolve time: 3.40s
# Presolved: 11810 rows, 1109075 columns, 2332600 nonzeros
# Variable types: 0 continuous, 1109075 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    34216    1.0630221e+06   0.000000e+00   1.599875e+07      5s
# Concurrent spin time: 0.80s
#
# Solved with dual simplex
#
# Root relaxation: objective 5.905490e+05, 89839 iterations, 4.09 seconds
# Total elapsed time = 14.04s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 590549.000    0   72 1982220.00 590549.000  70.2%     -   15s
# H    0     0                    590551.00000 590549.000  0.00%     -   16s
#
# Explored 1 nodes (245644 simplex iterations) in 16.34 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 590551 1.98222e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 5.905510000000e+05, best bound 5.905490000000e+05, gap 0.0003%
#
# Tempo de execução: 16.36210012435913; Número de variáveis: 1109075
#
#
# SOL. DA INSTÂNCIA COM 450 CLIENTES:
#
# Changed value of parameter TimeLimit to 1800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (linux64)
# Optimize a model with 16992 rows, 1867320 columns and 3906630 nonzeros
# Model fingerprint: 0x1318e628
# Variable types: 0 continuous, 1867320 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
# Found heuristic solution: objective 2243296.0000
# Presolve removed 0 rows and 0 columns (presolve time = 5s) ...
# Presolve time: 5.62s
# Presolved: 16992 rows, 1867320 columns, 3906630 nonzeros
# Variable types: 0 continuous, 1867320 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.4398890e+06   2.027625e+03   7.473699e+11      8s
#   123941    9.0477765e+05   0.000000e+00   3.513514e+07     10s
# Concurrent spin time: 1.05s
#
# Solved with dual simplex
#
# Root relaxation: objective 6.578572e+05, 84465 iterations, 5.63 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 657857.250    0   22 2243296.00 657857.250  70.7%     -   21s
# H    0     0                    657859.00000 657857.250  0.00%     -   22s
#
# Explored 1 nodes (317715 simplex iterations) in 22.40 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 657859 2.2433e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 6.578590000000e+05, best bound 6.578572500000e+05, gap 0.0003%
#
# Tempo de execução: 22.438735961914062; Número de variáveis: 1867320
#
#
# SOL. DA INSTÂNCIA COM 500 CLIENTES:
#
# Changed value of parameter TimeLimit to 1800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (linux64)
# Optimize a model with 19790 rows, 2297750 columns and 4800250 nonzeros
# Model fingerprint: 0xf6c122d8
# Variable types: 0 continuous, 2297750 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
# Found heuristic solution: objective 2549172.0000
# Presolve removed 0 rows and 0 columns (presolve time = 5s) ...
# Presolve time: 7.14s
# Presolved: 19790 rows, 2297750 columns, 4800250 nonzeros
# Variable types: 0 continuous, 2297750 integer (0 binary)
#
# Deterministic concurrent LP optimizer: primal and dual simplex
# Showing first log only...
#
#
# Root simplex log...
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7124780e+06   2.252312e+03   9.258645e+11     11s
#   308034    8.2023348e+05   0.000000e+00   2.386713e+06     15s
#   467930    7.4308275e+05   0.000000e+00   0.000000e+00     20s
# Concurrent spin time: 0.83s
#
# Solved with primal simplex
#
# Root relaxation: objective 7.430828e+05, 467930 iterations, 11.54 seconds
# Total elapsed time = 38.18s
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 743082.750    0   10 2549172.00 743082.750  70.9%     -   58s
# H    0     0                    743083.00000 743082.750  0.00%     -   59s
#      0     0 743082.750    0   10 743083.000 743082.750  0.00%     -   59s
#
# Explored 1 nodes (1486327 simplex iterations) in 59.15 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 2: 743083 2.54917e+06
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 7.430830000000e+05, best bound 7.430830000000e+05, gap 0.0000%
#
# Tempo de execução: 59.19118881225586; Número de variáveis: 2297750

# %% [markdown]
# #### **Modelo PL**: com as restrições de integralidade relaxadas.

# %%
for inst in instances:
    print('\nSOL. DA INSTÂNCIA COM ' + str(inst['J']) + ' CLIENTES:\n')
    
    # Criar modelo relaxado
    model = create_model(inst, relaxed = True)
    
    # Computar solução ótima
    model.optimize()
    
    # Relatar outros dados
    print(
        '\nTempo de execução: ' + 
        str(model.runTime) + 
        '; Número de variáveis: ' + 
        str(model.numVars) + 
        '\n'
    )
# Out:
# SOL. DA INSTÂNCIA COM 50 CLIENTES:
#
# Using license file /home/eduinnarelli/gurobi.lic
# Academic license - for non-commercial use only
# Changed value of parameter TimeLimit to 1800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (linux64)
# Optimize a model with 2122 rows, 36736 columns and 101024 nonzeros
# Model fingerprint: 0x9e691a63
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Presolve time: 0.06s
# Presolved: 2122 rows, 36736 columns, 101024 nonzeros
#
# Ordering time: 0.00s
#
# Barrier statistics:
#  AA' NZ     : 4.649e+04
#  Factor NZ  : 2.226e+05 (roughly 17 MBytes of memory)
#  Factor Ops : 5.236e+07 (less than 1 second per iteration)
#  Threads    : 3
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5
#        0 PPushes remaining with PInf 0.0000000e+00                 0s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      0s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     1267    1.4838700e+05   0.000000e+00   0.000000e+00      0s
#
# Solved with barrier
# Solved in 1267 iterations and 0.39 seconds
# Optimal objective  1.483870000e+05
#
# Tempo de execução: 0.38683199882507324; Número de variáveis: 72360
#
#
# SOL. DA INSTÂNCIA COM 150 CLIENTES:
#
# Changed value of parameter TimeLimit to 1800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (linux64)
# Optimize a model with 6468 rows, 279930 columns and 641130 nonzeros
# Model fingerprint: 0x09251779
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Presolve time: 0.28s
# Presolved: 6468 rows, 279930 columns, 641130 nonzeros
#
# Ordering time: 0.14s
#
# Barrier statistics:
#  AA' NZ     : 3.171e+05
#  Factor NZ  : 1.931e+06 (roughly 130 MBytes of memory)
#  Factor Ops : 1.445e+09 (less than 1 second per iteration)
#  Threads    : 3
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   4.78251337e+08  0.00000000e+00  1.55e+04 0.00e+00  4.52e+03     1s
#    1   4.93634128e+07 -3.49506723e+06  1.54e+03 2.22e+00  4.64e+02     1s
#    2   2.77713004e+06 -1.07516077e+06  0.00e+00 2.69e-01  1.38e+01     1s
#    3   1.58469277e+06 -4.81132698e+05  0.00e+00 1.50e-01  7.46e+00     1s
#    4   1.24512042e+06 -1.66643673e+05  0.00e+00 8.29e-02  5.07e+00     1s
#    5   5.35349136e+05 -7.45091873e+03  0.00e+00 1.93e-02  1.93e+00     1s
#    6   4.81009734e+05  2.27403020e+05  0.00e+00 7.32e-03  9.01e-01     1s
#    7   4.68415276e+05  2.57945923e+05  0.00e+00 5.37e-03  7.47e-01     1s
#    8   4.44329986e+05  2.69489562e+05  0.00e+00 4.55e-03  6.21e-01     1s
#    9   4.01268095e+05  2.85291429e+05  0.00e+00 2.41e-03  4.11e-01     1s
#   10   3.78967398e+05  3.00390551e+05  0.00e+00 7.86e-04  2.76e-01     1s
#   11   3.50417801e+05  3.03861621e+05  0.00e+00 2.33e-04  1.63e-01     1s
#   12   3.36216087e+05  3.07696856e+05  0.00e+00 6.96e-05  9.99e-02     2s
#   13   3.28406960e+05  3.08853947e+05  0.00e+00 4.43e-05  6.85e-02     2s
#   14   3.19379239e+05  3.10721645e+05  0.00e+00 6.22e-06  3.03e-02     2s
#   15   3.11900559e+05  3.11195939e+05  0.00e+00 2.84e-14  2.47e-03     2s
#   16   3.11301608e+05  3.11298984e+05  0.00e+00 4.26e-14  9.21e-06     2s
#   17   3.11299502e+05  3.11299499e+05  0.00e+00 2.84e-14  9.21e-09     2s
#
# Barrier solved model in 17 iterations and 1.88 seconds
# Optimal objective 3.11299502e+05
#
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                 2s
#
#     2019 PPushes remaining with PInf 0.0000000e+00                 2s
#        0 PPushes remaining with PInf 0.0000000e+00                 2s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00      2s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#     3594    3.1129950e+05   0.000000e+00   0.000000e+00      2s
#
# Solved with barrier
# Solved in 3594 iterations and 2.00 seconds
# Optimal objective  3.112995000e+05
#
# Tempo de execução: 2.001999855041504; Número de variáveis: 279930
#
#
# SOL. DA INSTÂNCIA COM 200 CLIENTES:
#
# Changed value of parameter TimeLimit to 1800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (linux64)
# Optimize a model with 6460 rows, 398520 columns and 865080 nonzeros
# Model fingerprint: 0x9616e09c
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Presolve time: 0.34s
# Presolved: 6460 rows, 398520 columns, 865080 nonzeros
#
# Ordering time: 0.18s
#
# Barrier statistics:
#  AA' NZ     : 4.257e+05
#  Factor NZ  : 1.921e+06 (roughly 180 MBytes of memory)
#  Factor Ops : 1.404e+09 (less than 1 second per iteration)
#  Threads    : 3
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   6
CLIENTES:
#
# Changed value of parameter TimeLimit to 1800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (linux64)
# Optimize a model with 16992 rows, 1867320 columns and 3906630 nonzeros
# Model fingerprint: 0xf93b0479
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Presolve time: 1.90s
# Presolved: 16992 rows, 1867320 columns, 3906630 nonzeros
#
# Ordering time: 5.22s
# Elapsed ordering time = 5s
# Ordering time: 6.97s
#
# Barrier performed 0 iterations in 29.54 seconds
# Barrier solve interrupted - model solved by another algorithm
#
#
# Solved with dual simplex
# Solved in 183799 iterations and 29.55 seconds
# Optimal objective  6.578572500e+05
#
# Tempo de execução: 29.620811939239502; Número de variáveis: 1867320
#
#
# SOL. DA INSTÂNCIA COM 500 CLIENTES:
#
# Changed value of parameter TimeLimit to 1800.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (linux64)
# Optimize a model with 19790 rows, 2297750 columns and 4800250 nonzeros
# Model fingerprint: 0x92ee966e
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [1e+01, 1e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# Concurrent LP optimizer: dual simplex and barrier
# Showing barrier log only...
#
# Presolve time: 2.65s
# Presolved: 19790 rows, 2297750 columns, 4800250 nonzeros
#
# Ordering time: 1.36s
# Ordering time: 2.79s
#
# Barrier statistics:
#  AA' NZ     : 2.412e+06
#  Factor NZ  : 1.330e+07 (roughly 1.0 GBytes of memory)
#  Factor Ops : 2.794e+10 (less than 1 second per iteration)
#  Threads    : 3
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   3.69914576e+09  0.00000000e+00  5.32e+04 0.00e+00  4.39e+03    34s
#    1   1.83360153e+08 -1.16672008e+07  2.50e+03 9.80e-02  2.16e+02    35s
#    2   8.50298445e+06 -2.93725961e+06  0.00e+00 1.17e-02  4.95e+00    36s
#    3   5.28371653e+06 -1.50119711e+06  0.00e+00 6.46e-03  2.93e+00    38s
#    4   2.48003590e+06 -7.03167248e+05  0.00e+00 2.80e-03  1.38e+00    39s
#    5   1.34720306e+06  3.23770960e+04  0.00e+00 2.99e-04  5.68e-01    41s
#    6   1.21734842e+06  6.28376756e+05  0.00e+00 2.84e-14  2.54e-01    43s
#    7   9.81459975e+05  6.87269287e+05  0.00e+00 2.84e-14  1.27e-01    44s
#    8   9.00613309e+05  7.13289809e+05  0.00e+00 2.84e-14  8.09e-02    45s
#    9   8.39609148e+05  7.30521080e+05  0.00e+00 2.84e-14  4.71e-02    46s
#   10   8.14095660e+05  7.31515196e+05  0.00e+00 2.84e-14  3.57e-02    47s
#   11   7.70872266e+05  7.38466568e+05  0.00e+00 2.84e-14  1.40e-02    48s
#   12   7.50747622e+05  7.42597328e+05  0.00e+00 2.84e-14  3.52e-03    49s
#   13   7.45533624e+05  7.43040274e+05  0.00e+00 4.26e-14  1.08e-03    50s
#   14   7.43698568e+05  7.43080204e+05  0.00e+00 2.84e-14  2.67e-04    51s
#   15   7.43085278e+05  7.43082731e+05  0.00e+00 2.84e-14  1.10e-06    53s
#   16   7.43082753e+05  7.43082750e+05  2.96e-10 4.26e-14  1.10e-09    54s
#
# Barrier solved model in 16 iterations and 53.67 seconds
# Optimal objective 7.43082753e+05
#
# Crossover log...
#
#        0 DPushes remaining with DInf 0.0000000e+00                54s
#
#    23330 PPushes remaining with PInf 0.0000000e+00                54s
#        0 PPushes remaining with PInf 0.0000000e+00                54s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 0.0000000e+00     54s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    27676    7.4308275e+05   0.000000e+00   0.000000e+00     55s
#
# Solved with barrier
# Solved in 27676 iterations and 54.86 seconds
# Optimal objective  7.430827500e+05
#
# Tempo de execução: 54.87059211730957; Número de variáveis: 2297750
